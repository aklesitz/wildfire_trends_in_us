# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
pd.set_option('display.max_columns', 100)

# %%
oregon = pd.read_csv('fire-occurence_Oregon_20-22.csv')

# %%
oregon.shape
# Out:
# (23490, 38)

# %%
oregon.head()
# Out:
#    Serial FireCategory  FireYear Area      DistrictName     UnitName  \
# 0   58256         STAT      2000  EOA    Central Oregon     John Day
# 1   59312         STAT      2000  EOA  Northeast Oregon    La Grande
# 2   61657         STAT      2001  SOA  Southwest Oregon  Grants Pass
# 3   63735         STAT      2002  NOA       West Oregon    Philomath
# 4   68019         STAT      2003  NOA       West Oregon       Dallas
#
#   FullFireNumber       FireName Size_class  EstTotalAcres  Protected_Acres  \
# 0   00-952011-01   Slick Ear #2          B           0.75             0.75
# 1   00-971024-01        Woodley          C          80.00            80.00
# 2   01-712133-02  QUEENS BRANCH          A           0.10             0.10
# 3   02-551001-03           WREN          A           0.01             0.01
# 4   03-552013-04   Ritner Creek          A           0.01             0.01
#
#   HumanOrLightning    CauseBy GeneralCause           SpecificCause  \
# ...

# %%
oregon.columns
# Out:
# Index(['Serial', 'FireCategory', 'FireYear', 'Area', 'DistrictName',
#        'UnitName', 'FullFireNumber', 'FireName', 'Size_class', 'EstTotalAcres',
#        'Protected_Acres', 'HumanOrLightning', 'CauseBy', 'GeneralCause',
#        'SpecificCause', 'Cause_Comments', 'Lat_DD', 'Long_DD', 'LatLongDD',
#        'FO_LandOwnType', 'Twn', 'Rng', 'Sec', 'Subdiv', 'LandmarkLocation',
#        'County', 'RegUseZone', 'RegUseRestriction', 'Industrial_Restriction',
#        'Ign_DateTime', 'ReportDateTime', 'Discover_DateTime',
#        'Control_DateTime', 'CreationDate', 'ModifiedDate', 'DistrictCode',
#        'UnitCode', 'DistFireNumber'],
#       dtype='object')

# %%
oregon.dtypes
# Out:
# Serial                      int64
# FireCategory               object
# FireYear                    int64
# Area                       object
# DistrictName               object
# UnitName                   object
# FullFireNumber             object
# FireName                   object
# Size_class                 object
# EstTotalAcres             float64
# Protected_Acres           float64
# HumanOrLightning           object
# CauseBy                    object
# GeneralCause               object
# SpecificCause              object
# Cause_Comments             object
# Lat_DD                    float64
# Long_DD                   float64
# LatLongDD                  object
# FO_LandOwnType             object
# Twn                        object
# Rng                        object
# Sec                       float64
# Subdiv                     object
# LandmarkLocation           object
# County                     object
# RegUseZone                 object
# ...

# %%
oregon.describe()
# Out:
#               Serial     FireYear  EstTotalAcres  Protected_Acres  \
# count   23490.000000  23490.00000   23411.000000     23490.000000
# mean    90425.933461   2010.80132     270.802503        63.454008
# std     20901.016028      6.73508    6816.736966      1973.577812
# min     57485.000000   2000.00000       0.000000         0.000000
# 25%     72508.500000   2005.00000       0.010000         0.010000
# 50%     88340.000000   2011.00000       0.100000         0.100000
# 75%    107432.500000   2017.00000       0.500000         0.350000
# max    134021.000000   2022.00000  499945.000000    154570.000000
#
#              Lat_DD       Long_DD           Sec  DistrictCode      UnitCode
# count  23480.000000  23480.000000  23478.000000  23490.000000  23490.000000
# mean      43.718410   -122.258736     18.576753     77.754662    779.371052
# std        1.226385      1.707589     10.439507     14.618857    146.534574
# ...

# %%
oregon = oregon[[#'Serial', 
        #'FireCategory', 
        'FireYear', #'Area', \
    'DistrictName',
       #'UnitName', 'FullFireNumber', 
    'FireName', 'Size_class', 'EstTotalAcres',
      # 'Protected_Acres', 
        #'HumanOrLightning',
        'CauseBy', 'GeneralCause',
       'SpecificCause',# 'Cause_Comments', 
    'Lat_DD', 'Long_DD', 
        #'LatLongDD',
      # 'FO_LandOwnType', 
        #'Twn', 'Rng', 'Sec', 'Subdiv', 
       # 'LandmarkLocation',
       'County', #'RegUseZone', 'RegUseRestriction', 'Industrial_Restriction',
       'Ign_DateTime', 'ReportDateTime', 'Discover_DateTime',
       'Control_DateTime', 'CreationDate', 'ModifiedDate', 'DistrictCode',#'UnitCode', 'DistFireNumber'
]].copy()

# %%
oregon.dtypes
# Out:
# FireYear               int64
# DistrictName          object
# FireName              object
# Size_class            object
# EstTotalAcres        float64
# CauseBy               object
# GeneralCause          object
# SpecificCause         object
# Lat_DD               float64
# Long_DD              float64
# County                object
# Ign_DateTime          object
# ReportDateTime        object
# Discover_DateTime     object
# Control_DateTime      object
# CreationDate          object
# ModifiedDate          object
# DistrictCode           int64
# dtype: object

# %%
oregon.head(1)
# Out:
#    FireYear    DistrictName      FireName Size_class  EstTotalAcres  \
# 0      2000  Central Oregon  Slick Ear #2          B           0.75
#
#      CauseBy GeneralCause SpecificCause    Lat_DD    Long_DD County  \
# 0  Lightning    Lightning     Lightning  44.91519 -119.28863  Grant
#
#              Ign_DateTime          ReportDateTime       Discover_DateTime  \
# 0  07/18/2000 07:00:00 PM  07/19/2000 01:20:00 PM  07/19/2000 01:15:00 PM
#
#          Control_DateTime            CreationDate            ModifiedDate  \
# 0  07/20/2000 12:50:00 AM  07/20/2000 09:13:00 AM  11/14/2000 09:16:00 AM
#
#    DistrictCode
# 0            95

# %%
oregon['Ign_DateTime'] = oregon['Ign_DateTime'] = pd.to_datetime(oregon['Ign_DateTime'])
oregon['ReportDateTime'] = oregon['ReportDateTime'] = pd.to_datetime(oregon['ReportDateTime'])
oregon['Discover_DateTime'] = oregon['Discover_DateTime'] = pd.to_datetime(oregon['Discover_DateTime'])
oregon['Control_DateTime'] = pd.to_datetime(oregon['Control_DateTime'])
oregon['CreationDate'] = pd.to_datetime(oregon['CreationDate'])
oregon['ModifiedDate'] = pd.to_datetime(oregon['ModifiedDate'])

# %%
oregon.dtypes
# Out:
# FireYear                      int64
# DistrictName                 object
# FireName                     object
# Size_class                   object
# EstTotalAcres               float64
# CauseBy                      object
# GeneralCause                 object
# SpecificCause                object
# Lat_DD                      float64
# Long_DD                     float64
# County                       object
# Ign_DateTime         datetime64[ns]
# ReportDateTime       datetime64[ns]
# Discover_DateTime    datetime64[ns]
# Control_DateTime     datetime64[ns]
# CreationDate         datetime64[ns]
# ModifiedDate         datetime64[ns]
# DistrictCode                  int64
# dtype: object

# %%
oregon.head(1)
# Out:
#    FireYear    DistrictName      FireName Size_class  EstTotalAcres  \
# 0      2000  Central Oregon  Slick Ear #2          B           0.75
#
#      CauseBy GeneralCause SpecificCause    Lat_DD    Long_DD County  \
# 0  Lightning    Lightning     Lightning  44.91519 -119.28863  Grant
#
#          Ign_DateTime      ReportDateTime   Discover_DateTime  \
# 0 2000-07-18 19:00:00 2000-07-19 13:20:00 2000-07-19 13:15:00
#
#      Control_DateTime        CreationDate        ModifiedDate  DistrictCode
# 0 2000-07-20 00:50:00 2000-07-20 09:13:00 2000-11-14 09:16:00            95

# %%
oregon = oregon.rename(columns={'Size_class':'SizeClass', 
                      'Protected_Acres':'ProtectedAcres',
                      'Cause_Comments':'CauseComments',
                      'Lat_DD':'Lat',
                      'Long_DD':'Long',
                      'FO_LandOwnType':'LandOwn',
                      'Industrial_Restriction':'IndustrialRestriction'})

# %%
oregon.loc[oregon.duplicated()]
# Out:
# Empty DataFrame
# Columns: [FireYear, DistrictName, FireName, SizeClass, EstTotalAcres, CauseBy, GeneralCause, SpecificCause, Lat, Long, County, Ign_DateTime, ReportDateTime, Discover_DateTime, Control_DateTime, CreationDate, ModifiedDate, DistrictCode]
# Index: []

# %%
oregon.loc[oregon.duplicated(subset=['FireName'])]
# Out:
#        FireYear      DistrictName       FireName SizeClass  EstTotalAcres  \
# 218        2000    Douglas - DFPA     Tater Hill         C          18.35
# 298        2005  Southwest Oregon        Hwy 234         A           0.01
# 355        2007    Central Oregon     Vandervert         A           0.01
# 373        2001    Central Oregon    Slide Creek         A           0.25
# 448        2003    Douglas - DFPA    Boomer Hill         A           0.01
# ...         ...               ...            ...       ...            ...
# 23457      2022     North Cascade   Bittner Mill         A           0.01
# 23464      2022  Northeast Oregon        Wilkins         A           0.10
# 23467      2022       Coos - CFPA     Lake Marie         A           0.02
# 23479      2022  Southwest Oregon  Moon Mountain         A           0.03
# 23481      2022  Southwest Oregon   Grouse Ridge         A           0.10
#
#              CauseBy    GeneralCause  \
# 218    Recreationist      Recreation
# ...

# %%
oregon.query('FireName == "Slide Creek"')
# Out:
#        FireYear      DistrictName     FireName SizeClass  EstTotalAcres  \
# 367        2004  Southwest Oregon  Slide Creek         A           0.25
# 373        2001    Central Oregon  Slide Creek         A           0.25
# 2271       2002    Douglas - DFPA  Slide Creek         A           0.10
# 2933       2004    Douglas - DFPA  Slide Creek         A           0.00
# 4973       2002    Central Oregon  Slide Creek         B           1.00
# 7189       2000       Coos - CFPA  Slide Creek         A           0.01
# 13119      2012       West Oregon  Slide Creek         A           0.01
# 14723      2014    Douglas - DFPA  Slide Creek         A           0.01
# 18920      2019    Central Oregon  Slide Creek         A           0.10
# 19141      2019    Central Oregon  Slide Creek         A           0.10
# 19202      2021       Coos - CFPA  Slide Creek         B           2.44
# 22017      2019    Douglas - DFPA  Slide Creek         A           0.10
#
# ...

# %%
oregon.duplicated(subset=['FireYear','FireName','DistrictName']).sum()
# Out:
# 134

# %%
oregon.duplicated().sum()
# Out:
# 0

# %%
oregon.isnull().sum()
# Out:
# FireYear               0
# DistrictName           0
# FireName               0
# SizeClass              0
# EstTotalAcres         79
# CauseBy              128
# GeneralCause           0
# SpecificCause        224
# Lat                   10
# Long                  10
# County                 0
# Ign_DateTime          94
# ReportDateTime         0
# Discover_DateTime     94
# Control_DateTime      95
# CreationDate           3
# ModifiedDate           0
# DistrictCode           0
# dtype: int64

# %%
oregon['FireYear'].value_counts()
# Out:
# 2006    1342
# 2001    1289
# 2007    1239
# 2013    1186
# 2002    1175
# 2003    1174
# 2021    1134
# 2014    1119
# 2018    1112
# 2017    1090
# 2008    1088
# 2015    1079
# 2019    1020
# 2009     990
# 2020     983
# 2004     921
# 2000     921
# 2022     888
# 2016     832
# 2005     827
# 2011     699
# 2010     693
# 2012     689
# Name: FireYear, dtype: int64

# %%
FireBar = oregon['FireYear'].value_counts()\
    .plot(kind= 'bar', title='Most Common Year For Fires')
FireBar.set_xlabel('Year')
FireBar.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
oregon
# Out:
#        FireYear          DistrictName       FireName SizeClass  EstTotalAcres  \
# 0          2000        Central Oregon   Slick Ear #2         B           0.75
# 1          2000      Northeast Oregon        Woodley         C          80.00
# 2          2001      Southwest Oregon  QUEENS BRANCH         A           0.10
# 3          2002           West Oregon           WREN         A           0.01
# 4          2003           West Oregon   Ritner Creek         A           0.01
# ...         ...                   ...            ...       ...            ...
# 23485      2021  Walker Range - WRFPA      Road 2430         B           0.75
# 23486      2022          Western Lane    Spruce Path         A           0.01
# 23487      2021      Northeast Oregon    Bone Canyon         C          67.43
# 23488      2022      Northeast Oregon   Milepost 231         A           0.10
# 23489      2022        Central Oregon   That Way 774         A           0.01
#
# ...

# %%
DistrictBar = oregon['DistrictName'].value_counts()\
    .plot(kind= 'bar', title='Most Common District')
DistrictBar.set_xlabel('Year')
DistrictBar.set_ylabel('Count');

# %%
FireClass = oregon['SizeClass'].value_counts()\
    .plot(kind= 'bar', title='Most Common Class For Fires')
FireClass.set_xlabel('Year')
FireClass.set_ylabel('Count');

# %%
oregon.head(1)
# Out:
#    FireYear    DistrictName      FireName SizeClass  EstTotalAcres    CauseBy  \
# 0      2000  Central Oregon  Slick Ear #2         B           0.75  Lightning
#
#   GeneralCause SpecificCause       Lat       Long County        Ign_DateTime  \
# 0    Lightning     Lightning  44.91519 -119.28863  Grant 2000-07-18 19:00:00
#
#        ReportDateTime   Discover_DateTime    Control_DateTime  \
# 0 2000-07-19 13:20:00 2000-07-19 13:15:00 2000-07-20 00:50:00
#
#          CreationDate        ModifiedDate  DistrictCode
# 0 2000-07-20 09:13:00 2000-11-14 09:16:00            95

# %%
oregon.plot(kind='scatter',
           x='FireYear',
           y='EstTotalAcres');

# %%
oregon = oregon.drop(10911)

# %%
oregon.loc[oregon['EstTotalAcres']>400000]
# Biscuit Fire and Bootleg Fire, Oregon's two biggest wildfires
# serial 10911 appears to be a part of the Biscuit Fire, and will be removed
# Out:
#        FireYear      DistrictName       FireName SizeClass  EstTotalAcres  \
# 10897      2002  Southwest Oregon  ODF / BISCUIT         G       499945.0
# 22832      2021      Klamath-Lake    Bootleg 321         G       413744.0
#
#          CauseBy GeneralCause SpecificCause       Lat       Long     County  \
# 10897  Lightning    Lightning     Lightning  42.40541 -123.89194  Josephine
# 22832  Lightning    Lightning     Lightning  42.61583 -121.42083    Klamath
#
#              Ign_DateTime      ReportDateTime   Discover_DateTime  \
# 10897 2002-07-13 14:30:00 2002-07-15 12:14:00 2002-07-15 12:13:00
# 22832 2021-06-24 16:35:00 2021-07-06 13:42:00 2021-07-06 13:42:00
#
#          Control_DateTime        CreationDate        ModifiedDate  \
# 10897 2002-11-08 18:00:00 2002-08-19 18:28:00 2002-12-09 16:46:00
# 22832 2021-12-02 09:29:00 2021-07-06 00:00:00 2022-03-24 09:38:00
#
#        DistrictCode
# 10897            71
# 22832            98

# %%
# Takes away outliers: Bootstrap and Biscuit wildfires
oregon = oregon.drop(10897)
oregon = oregon.drop(22832)

# %%
sns.scatterplot(x='FireYear',
               y='EstTotalAcres',
                hue='SizeClass',
               data=oregon);

# %%
oregon.head(1)
# Out:
#    FireYear    DistrictName      FireName SizeClass  EstTotalAcres    CauseBy  \
# 0      2000  Central Oregon  Slick Ear #2         B           0.75  Lightning
#
#   GeneralCause SpecificCause       Lat       Long County        Ign_DateTime  \
# 0    Lightning     Lightning  44.91519 -119.28863  Grant 2000-07-18 19:00:00
#
#        ReportDateTime   Discover_DateTime    Control_DateTime  \
# 0 2000-07-19 13:20:00 2000-07-19 13:15:00 2000-07-20 00:50:00
#
#          CreationDate        ModifiedDate  DistrictCode
# 0 2000-07-20 09:13:00 2000-11-14 09:16:00            95

# %%
oregon_corr = oregon[['FireYear', 'EstTotalAcres']].dropna().corr()
oregon_corr
# Out:
#                FireYear  EstTotalAcres
# FireYear       1.000000       0.026685
# EstTotalAcres  0.026685       1.000000

# %%
sns.heatmap(oregon_corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
oregon.head(1)
# Out:
#    FireYear    DistrictName      FireName SizeClass  EstTotalAcres    CauseBy  \
# 0      2000  Central Oregon  Slick Ear #2         B           0.75  Lightning
#
#   GeneralCause SpecificCause       Lat       Long County        Ign_DateTime  \
# 0    Lightning     Lightning  44.91519 -119.28863  Grant 2000-07-18 19:00:00
#
#        ReportDateTime   Discover_DateTime    Control_DateTime  \
# 0 2000-07-19 13:20:00 2000-07-19 13:15:00 2000-07-20 00:50:00
#
#          CreationDate        ModifiedDate  DistrictCode
# 0 2000-07-20 09:13:00 2000-11-14 09:16:00            95

# %%
oregon.groupby('DistrictName')['EstTotalAcres'].agg(['mean','count']).sort_values('mean', ascending=False)
# Out:
#                             mean  count
# DistrictName
# Northeast Oregon      614.980952   1806
# North Cascade         429.929032   1384
# Central Oregon        336.607110   3339
# Klamath-Lake          300.665144   1985
# Coos - CFPA           253.355147   1461
# South Cascade         200.473763   1366
# Douglas - DFPA        122.980280   2142
# Southwest Oregon       96.734403   5973
# West Oregon             6.685321    778
# Western Lane            3.747747   1176
# Astoria                 2.983732    418
# Tillamook               2.696978    278
# Walker Range - WRFPA    2.573592    476
# Forest Grove            1.993547    826

# %%
california = pd.read_csv('California_Fire_13-20.csv')

# %%
california.head(1)
# Out:
#    AcresBurned  Active                                          AdminUnit  \
# 0     257314.0   False  Stanislaus National Forest/Yosemite National Park
#
#    AirTankers  ArchiveYear  CalFireIncident                    CanonicalUrl  \
# 0         NaN         2013             True  /incidents/2013/8/17/rim-fire/
#
#   ConditionStatement ControlStatement  Counties CountyIds  CrewsInvolved  \
# 0                NaN              NaN  Tuolumne        55            NaN
#
#    Dozers  Engines          Extinguished  Fatalities  Featured  Final  \
# 0     NaN      NaN  2013-09-06T18:30:00Z         NaN     False   True
#
#   FuelType  Helicopters  Injuries  Latitude  \
# 0      NaN          NaN       NaN    37.857
#
#                                   Location  Longitude  MajorIncident  \
# 0  3 miles east of Groveland along Hwy 120   -120.086          False
#
#        Name  PercentContained  PersonnelInvolved  Public  \
# 0  Rim Fire             100.0                NaN    True
#
# ...

# %%
california = california[['AcresBurned', #'Active', 'AdminUnit', 'AirTankers', 
                         'ArchiveYear',
       #'CalFireIncident', 'CanonicalUrl', 'ConditionStatement',
       #'ControlStatement', 
                         'Counties', 'CountyIds', #'CrewsInvolved', 'Dozers',
       #'Engines', 
                         'Extinguished',
                         #'Fatalities', 'Featured', 'Final',
       #'FuelType', 'Helicopters', 'Injuries', 
                         'Latitude', 'Location',
       'Longitude', #'MajorIncident', 
                         'Name',
                         #'PercentContained',
       #'PersonnelInvolved', 'Public', 'SearchDescription', 'SearchKeywords',
       'Started']]
                         #'Status', 'StructuresDamaged', 'StructuresDestroyed',
       #'StructuresEvacuated', 'StructuresThreatened', 'UniqueId', 'Updated',
       #'WaterTenders']]

# %%
california.dtypes
# Out:
# AcresBurned     float64
# ArchiveYear       int64
# Counties         object
# CountyIds        object
# Extinguished     object
# Latitude        float64
# Location         object
# Longitude       float64
# Name             object
# Started          object
# dtype: object

# %%
california.columns
# Out:
# Index(['AcresBurned', 'ArchiveYear', 'Counties', 'CountyIds', 'Extinguished',
#        'Latitude', 'Location', 'Longitude', 'Name', 'Started'],
#       dtype='object')

# %%
california.head(1)
# Out:
#    AcresBurned  ArchiveYear  Counties CountyIds          Extinguished  \
# 0     257314.0         2013  Tuolumne        55  2013-09-06T18:30:00Z
#
#    Latitude                                 Location  Longitude      Name  \
# 0    37.857  3 miles east of Groveland along Hwy 120   -120.086  Rim Fire
#
#                 Started
# 0  2013-08-17T15:25:00Z

# %%
oregon.head(1)
# Out:
#    FireYear    DistrictName      FireName SizeClass  EstTotalAcres    CauseBy  \
# 0      2000  Central Oregon  Slick Ear #2         B           0.75  Lightning
#
#   GeneralCause SpecificCause       Lat       Long County        Ign_DateTime  \
# 0    Lightning     Lightning  44.91519 -119.28863  Grant 2000-07-18 19:00:00
#
#        ReportDateTime   Discover_DateTime    Control_DateTime  \
# 0 2000-07-19 13:20:00 2000-07-19 13:15:00 2000-07-20 00:50:00
#
#          CreationDate        ModifiedDate  DistrictCode
# 0 2000-07-20 09:13:00 2000-11-14 09:16:00            95

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(oregon, title='Oregon Wildfires')

# %%
profile.to_file('oregon_wildfires.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile = ProfileReport(california, title="California Wildfires")
profile.to_file('california_wildfires.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
total_fires = pd.read_csv('2.3mil_92-20.csv',dtype=object)

# %%
total_fires.columns
# Out:
# Index(['OBJECTID', 'Shape', 'FOD_ID', 'FPA_ID', 'SOURCE_SYSTEM_TYPE',
#        'SOURCE_SYSTEM', 'NWCG_REPORTING_AGENCY', 'NWCG_REPORTING_UNIT_ID',
#        'NWCG_REPORTING_UNIT_NAME', 'SOURCE_REPORTING_UNIT',
#        'SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID',
#        'LOCAL_INCIDENT_ID', 'FIRE_CODE', 'FIRE_NAME',
#        'ICS_209_PLUS_INCIDENT_JOIN_ID', 'ICS_209_PLUS_COMPLEX_JOIN_ID',
#        'MTBS_ID', 'MTBS_FIRE_NAME', 'COMPLEX_NAME', 'FIRE_YEAR',
#        'DISCOVERY_DATE', 'DISCOVERY_DOY', 'DISCOVERY_TIME',
#        'NWCG_CAUSE_CLASSIFICATION', 'NWCG_GENERAL_CAUSE',
#        'NWCG_CAUSE_AGE_CATEGORY', 'CONT_DATE', 'CONT_DOY', 'CONT_TIME',
#        'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE', 'LONGITUDE', 'OWNER_DESCR',
#        'STATE', 'COUNTY', 'FIPS_CODE', 'FIPS_NAME'],
#       dtype='object')

# %%
total_fires.head(1)
# Out:
#   OBJECTID                                              Shape FOD_ID  \
# 0        1  b'\x00\x01\xad\x10\x00\x00\xc8\xce\n[_@^\xc0\x...      1
#
#        FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM NWCG_REPORTING_AGENCY  \
# 0  FS-1418826                FED   FS-FIRESTAT                    FS
#
#   NWCG_REPORTING_UNIT_ID NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 0                USCAPNF   Plumas National Forest                  0511
#
#   SOURCE_REPORTING_UNIT_NAME LOCAL_FIRE_REPORT_ID LOCAL_INCIDENT_ID FIRE_CODE  \
# 0     Plumas National Forest                    1            PNF-47      BJ8K
#
#   FIRE_NAME ICS_209_PLUS_INCIDENT_JOIN_ID ICS_209_PLUS_COMPLEX_JOIN_ID  \
# 0  FOUNTAIN                           NaN                          NaN
#
#   MTBS_ID MTBS_FIRE_NAME COMPLEX_NAME FIRE_YEAR DISCOVERY_DATE DISCOVERY_DOY  \
# 0     NaN            NaN          NaN      2005       2/2/2005            33
#
#   DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# ...

# %%
total_fires = total_fires[['SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID','FIRE_NAME','FIRE_YEAR',
           'DISCOVERY_DATE', 'DISCOVERY_DOY', 'DISCOVERY_TIME',
           'NWCG_CAUSE_CLASSIFICATION', 'NWCG_GENERAL_CAUSE',
           'NWCG_CAUSE_AGE_CATEGORY', 'CONT_DATE', 'CONT_DOY', 'CONT_TIME',
           'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE', 'LONGITUDE', 'OWNER_DESCR',
           'STATE', 'COUNTY', 'FIPS_CODE', 'FIPS_NAME']]

# %%
total_fires['DISCOVERY_TIME']
# Out:
# 0          1300
# 1          0845
# 2          1921
# 3          1600
# 4          1600
#            ...
# 2303561    1741
# 2303562    1958
# 2303563    1911
# 2303564    0755
# 2303565    1110
# Name: DISCOVERY_TIME, Length: 2303566, dtype: object

# %%
total_fires.head(1)
# Out:
#   SOURCE_REPORTING_UNIT_NAME LOCAL_FIRE_REPORT_ID FIRE_NAME FIRE_YEAR  \
# 0     Plumas National Forest                    1  FOUNTAIN      2005
#
#   DISCOVERY_DATE DISCOVERY_DOY DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# 0       2/2/2005            33           1300                     Human
#
#                            NWCG_GENERAL_CAUSE NWCG_CAUSE_AGE_CATEGORY  \
# 0  Power generation/transmission/distribution                     NaN
#
#   CONT_DATE CONT_DOY CONT_TIME FIRE_SIZE FIRE_SIZE_CLASS     LATITUDE  \
# 0  2/2/2005       33      1730       0.1               A  40.03694444
#
#        LONGITUDE OWNER_DESCR STATE COUNTY FIPS_CODE      FIPS_NAME
# 0  -121.00583333        USFS    CA     63     06063  Plumas County

# %%
total_fires['DISCOVERY_DATE'] = pd.to_datetime(total_fires['DISCOVERY_DATE'])
total_fires['DISCOVERY_DOY'] = total_fires['DISCOVERY_DOY'].astype(int)
#total_fires['DISCOVERY_TIME'] = total_fires['DISCOVERY_TIME'].astype(int)
total_fires['CONT_DATE'] = pd.to_datetime(total_fires['CONT_DATE'])
#total_fires['CONT_DOY'] = total_fires['CONT_DOY'].astype(int)
total_fires['FIRE_SIZE'] = total_fires['FIRE_SIZE'].astype(float)
total_fires['LATITUDE'] = total_fires['LATITUDE'].astype(float)
total_fires['LONGITUDE'] = total_fires['LONGITUDE'].astype(float)

# %%
total_fires.dtypes
# Out:
# SOURCE_REPORTING_UNIT_NAME            object
# LOCAL_FIRE_REPORT_ID                  object
# FIRE_NAME                             object
# FIRE_YEAR                             object
# DISCOVERY_DATE                datetime64[ns]
# DISCOVERY_DOY                          int32
# DISCOVERY_TIME                        object
# NWCG_CAUSE_CLASSIFICATION             object
# NWCG_GENERAL_CAUSE                    object
# NWCG_CAUSE_AGE_CATEGORY               object
# CONT_DATE                     datetime64[ns]
# CONT_DOY                              object
# CONT_TIME                             object
# FIRE_SIZE                            float64
# FIRE_SIZE_CLASS                       object
# LATITUDE                             float64
# LONGITUDE                            float64
# OWNER_DESCR                           object
# STATE                                 object
# COUNTY                                object
# FIPS_CODE                             object
# ...

# %%
total_fires.head(1)
# Out:
#   SOURCE_REPORTING_UNIT_NAME LOCAL_FIRE_REPORT_ID FIRE_NAME FIRE_YEAR  \
# 0     Plumas National Forest                    1  FOUNTAIN      2005
#
#   DISCOVERY_DATE  DISCOVERY_DOY DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# 0     2005-02-02             33           1300                     Human
#
#                            NWCG_GENERAL_CAUSE NWCG_CAUSE_AGE_CATEGORY  \
# 0  Power generation/transmission/distribution                     NaN
#
#    CONT_DATE CONT_DOY CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0 2005-02-02       33      1730        0.1               A  40.036944
#
#     LONGITUDE OWNER_DESCR STATE COUNTY FIPS_CODE      FIPS_NAME
# 0 -121.005833        USFS    CA     63     06063  Plumas County

# %%
total_fires.isnull().sum()
# Out:
# SOURCE_REPORTING_UNIT_NAME          0
# LOCAL_FIRE_REPORT_ID          1825891
# FIRE_NAME                      995415
# FIRE_YEAR                           0
# DISCOVERY_DATE                      0
# DISCOVERY_DOY                       0
# DISCOVERY_TIME                 789095
# NWCG_CAUSE_CLASSIFICATION           0
# NWCG_GENERAL_CAUSE                  0
# NWCG_CAUSE_AGE_CATEGORY       2228039
# CONT_DATE                      894813
# CONT_DOY                       894813
# CONT_TIME                      990880
# FIRE_SIZE                           0
# FIRE_SIZE_CLASS                     0
# LATITUDE                            0
# LONGITUDE                           0
# OWNER_DESCR                         0
# STATE                               0
# COUNTY                         665779
# FIPS_CODE                      665779
# FIPS_NAME                      665780
# dtype: int64

# %%
total_fires.drop('LOCAL_FIRE_REPORT_ID', axis=1, inplace=True)

# %%
total_fires.drop('NWCG_CAUSE_AGE_CATEGORY', axis=1, inplace=True)

# %%
total_fires.head(1)
# Out:
#   SOURCE_REPORTING_UNIT_NAME FIRE_NAME FIRE_YEAR DISCOVERY_DATE  \
# 0     Plumas National Forest  FOUNTAIN      2005     2005-02-02
#
#    DISCOVERY_DOY DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# 0             33           1300                     Human
#
#                            NWCG_GENERAL_CAUSE  CONT_DATE CONT_DOY CONT_TIME  \
# 0  Power generation/transmission/distribution 2005-02-02       33      1730
#
#    FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE   LONGITUDE OWNER_DESCR STATE COUNTY  \
# 0        0.1               A  40.036944 -121.005833        USFS    CA     63
#
#   FIPS_CODE      FIPS_NAME
# 0     06063  Plumas County

# %%
total_fires.isnull().sum()
# Out:
# SOURCE_REPORTING_UNIT_NAME         0
# FIRE_NAME                     995415
# FIRE_YEAR                          0
# DISCOVERY_DATE                     0
# DISCOVERY_DOY                      0
# DISCOVERY_TIME                789095
# NWCG_CAUSE_CLASSIFICATION          0
# NWCG_GENERAL_CAUSE                 0
# CONT_DATE                     894813
# CONT_DOY                      894813
# CONT_TIME                     990880
# FIRE_SIZE                          0
# FIRE_SIZE_CLASS                    0
# LATITUDE                           0
# LONGITUDE                          0
# OWNER_DESCR                        0
# STATE                              0
# COUNTY                        665779
# FIPS_CODE                     665779
# FIPS_NAME                     665780
# dtype: int64

# %%
total_fires['OWNER_DESCR'].nunique()
# Out:
# 17

# %%
total_fires.drop('COUNTY', axis=1, inplace=True)

# %%
total_fires.isnull().sum()
# Out:
# SOURCE_REPORTING_UNIT_NAME         0
# FIRE_NAME                     995415
# FIRE_YEAR                          0
# DISCOVERY_DATE                     0
# DISCOVERY_DOY                      0
# DISCOVERY_TIME                789095
# NWCG_CAUSE_CLASSIFICATION          0
# NWCG_GENERAL_CAUSE                 0
# CONT_DATE                     894813
# CONT_DOY                      894813
# CONT_TIME                     990880
# FIRE_SIZE                          0
# FIRE_SIZE_CLASS                    0
# LATITUDE                           0
# LONGITUDE                          0
# OWNER_DESCR                        0
# STATE                              0
# FIPS_CODE                     665779
# FIPS_NAME                     665780
# dtype: int64

# %%
fires_contained = total_fires[['CONT_DATE','CONT_DOY','CONT_TIME']]

# %%
total_fires.drop('CONT_DATE', axis=1, inplace=True)
total_fires.drop('CONT_DOY', axis=1, inplace=True)
total_fires.drop('CONT_TIME', axis=1, inplace=True)

# %%
total_fires.isnull().sum()
# Out:
# SOURCE_REPORTING_UNIT_NAME         0
# FIRE_NAME                     995415
# FIRE_YEAR                          0
# DISCOVERY_DATE                     0
# DISCOVERY_DOY                      0
# DISCOVERY_TIME                789095
# NWCG_CAUSE_CLASSIFICATION          0
# NWCG_GENERAL_CAUSE                 0
# FIRE_SIZE                          0
# FIRE_SIZE_CLASS                    0
# LATITUDE                           0
# LONGITUDE                          0
# OWNER_DESCR                        0
# STATE                              0
# FIPS_CODE                     665779
# FIPS_NAME                     665780
# dtype: int64

# %%
total_fires.head(1)
# Out:
#   SOURCE_REPORTING_UNIT_NAME FIRE_NAME FIRE_YEAR DISCOVERY_DATE  \
# 0     Plumas National Forest  FOUNTAIN      2005     2005-02-02
#
#    DISCOVERY_DOY DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# 0             33           1300                     Human
#
#                            NWCG_GENERAL_CAUSE  FIRE_SIZE FIRE_SIZE_CLASS  \
# 0  Power generation/transmission/distribution        0.1               A
#
#     LATITUDE   LONGITUDE OWNER_DESCR STATE FIPS_CODE      FIPS_NAME
# 0  40.036944 -121.005833        USFS    CA     06063  Plumas County

# %%
total_fires
# Out:
#                              SOURCE_REPORTING_UNIT_NAME        FIRE_NAME  \
# 0                                Plumas National Forest         FOUNTAIN
# 1                              Eldorado National Forest           PIGEON
# 2                              Eldorado National Forest            SLACK
# 3                              Eldorado National Forest             DEER
# 4                              Eldorado National Forest         STEVENOT
# ...                                                 ...              ...
# 2303561                     Grand Junction Field Office            JONES
# 2303562                            Merced-Mariposa Unit            POWER
# 2303563                      Bitterroot National Forest          12 MILE
# 2303564   Mid Columbia National Wildlife Refuge Complex      TAYLOR POND
# 2303565  George Washington & Jefferson National Forests  MIDDLE MOUNTAIN
#
#         FIRE_YEAR DISCOVERY_DATE  DISCOVERY_DOY DISCOVERY_TIME  \
# ...
